# %% [markdown]
# # Guide : extraction de catalogues numérisés
#
# *Artl@s / IMAGO / Université de Genève*
#
# **Ce guide explique comment utiliser le programme "extractionCatalogs"**
#
# En partant d'images numérisées de catalogues d'exposition d'art (XIXe et XXe siècle), ce script (programme) nous permet de produire des tableurs (ou autres types de fichiers) structurant toutes leurs informations : auteurs, oeuvres, informations complémentaires (adresses, entités spatiales, descriptions, associations académiques, prix, etc.).

# %%
# !python3 run.py tests_Esteban_input/PCP_1902/ tests_Esteban_output/ PCP_1902

# %% [markdown]
# ## Installation

# %% [markdown]
# ### Commandes d'installation

# %% [markdown]
# ### Commandes du script

# %% [markdown]
# ### utilisation du guide : Jupyter notebook

# %% [markdown]
# ## Reconnaissance de caractères avec eScriptorium

# %% [markdown]
# ## Utiliser le script extractionCatalogs

# %% [markdown]
# ### input ALTO

# %% [markdown]
# ### fonctionnement du script

# %% [markdown]
# Cette section décrit sommairement le fonctionnament du script, mais aussi comment le lire et le comprendre sans ce notebook. Le script est relativement complexe mais abondamment commenté, et ambitionne d'être transparent pour des utilisateurs néophytes.

# %% [markdown]
# ### output TEI

# %% [markdown]
# ### Informations sur le terminal

# %%
# !python3 run.py exemples_input/PCP_1902/ exemples_output/ PCP_1902
# Out:
# 1 – Traitement de cat_pcp_1902.pdf_page_9.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_9.xml traité
# 2 – Traitement de cat_pcp_1902.pdf_page_10.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	  Les <TextLine> de l'objet eSc_textblock_3588c694 se trouvent directement dans une 'MainZone'
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      ABBOTT (Yarnall).
# 	      15, rue Delambre, Paris.
# 		  1 Le Calice. D. Pl.
# 		  2 Coryphée. Gb.
# 		  3 Waldweben. D. Pl.
# 		  4 Le Ruisseau (Hiver). D. Pl.
# 		  5 Marie. Gb.
# 	      ADELOT (E.).
# 	       C. EFF. Bruxelles.
# 		  6 La Récolte des Chardons. Br.
# 	      ARENDSEN.
# 	      6, Molsteeg, Amsterdam, Hollande.
# 		  7 Avant la pluie. A. Br.
# 	cat_pcp_1902.pdf_page_10.xml traité
# 3 – Traitement de cat_pcp_1902.pdf_page_11.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      ASHTON (E.-R.).
# 	       L. R. Camden Park, Tunbridge Wells (Angleterre).
# 		  8 Chez le Grand Mogol.
# 		  9 Dévotions de l'après-midi.
# 	      BACHROUSCHINE (Wladimir).
# 	      PRÉS. DE LA SOC. DE PHOTOGR. ARTIST. DE MOSCOU. Moscou.
# 		  10 Sauguine. D. Gb. Fr.
# 		  11 Paysage. D. Gb. Fr.
# 		  12 Étude. D. Gb. Fr.
# 	      BAILLOU (Ernest).
# 	       P. C. P. - S. V. P. 71, boulevard de la Reine, Versailles (Seine-et-Oise).
# 		  13 L'Automne à Trianon. D. Br.
# 		  14 Le grand Canal, parc de Versailles. D. Br.
# 	      BAIRD (Miss A.).
# 	      37, avenue de l'Alma, Paris.
# 		  15 Une rue à Fribourg. A.
# 		  16 Après l'orage (Lac de Genève). D.
# 		  17 Orage (Lac de Genève). D.
# 	cat_pcp_1902.pdf_page_11.xml traité
# 4 – Traitement de cat_pcp_1902.pdf_page_12.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_12.xml traité
# 5 – Traitement de cat_pcp_1902.pdf_page_13.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BARUCCHI (Michel).
# 	      32, quai Saint-Jean-Baptiste, Nice (Alpes- Maritimes).
# 		  18 Effet de Soleil.
# 	      BÉGOZ (Alfred).
# 	      4, cité Hauteville, Paris.
# 		  19 Suzanne.
# 		  20 Dans le Verger.
# 		  21 Les Marguerites.
# 	      BÉGUIN.
# 	       A. B. DE PH. rue Henri-Blès, Namur (Belgique).
# 		  22 Paysage.
# 		  23 Étude.
# 	      BELLIENI (H.).
# 	       S. F. P. 17, Place Carnot, Nancy (Meurthe-et- Moselle).
# 		  24 Gardeuse d'oies. A. Ch.
# 		  25 Charge de Cuirassiers. A. Ch.
# 		  26 Brumes du matin. A Ch.
# 	      BELLIVET (G.).
# 	       AR. N. - P. C. P. Montclair, Mantega, Nice (Alpes-Maritimes).
# 		  27 Sous bois (Parc de Saint-Cloud). A. Br.
# 		  28 Environs de Nice. A. Br.
# 	cat_pcp_1902.pdf_page_13.xml traité
# 6 – Traitement de cat_pcp_1902.pdf_page_14.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BERGER (Paul).
# 	      62, rue Caumartin, Paris.
# 		  29 Portrait de Madame C... D. Ch.
# 		  30 Suzanne (Étude). D. Ch.
# 		  31 Fille de ferme. D. Ch.
# 	      BERGON (Paul).
# 	       P. C. P. 40, boulevard Haussmann, Paris.
# 		  32 Mélusine. Ch.
# 		  33 Incantation. Ch.
# 		  34 Portrait. Ch.
# 		  35 A la Source. Ch.
# 		  36 Vision. Ch.
# 		  37 Elle passe... Ch.
# 	      BERTRAND (Henri).
# 	      Dieulefit (Drôme).
# 		  38 Le Potier. A. Br.
# 	      BESSON (Georges).
# 	       P. C. P. - P. C. HAUT-JURA. 6, rue des Promenades, Saint-Claude (Jura).
# 		  39 La Halte. A. G. B.
# 		  40 Matinée d'Automne. A. Br.
# 		  41 Effet de Neige. D. Br.
# 		  42 Étude. D. Br.
# 	cat_pcp_1902.pdf_page_14.xml traité
# 7 – Traitement de cat_pcp_1902.pdf_page_15.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BIENDINÉ (A.).
# 		  72 bis, rue de la Paix, Boulogne-sur- Mer (Pas-de-Calais).
# 		  43 Au Coin du feu. Picardie.
# 	      BILLIOQUE (L.)
# 	      , PRÉSID. DE S. P. D'ARCACHON. Villa Durandal, Arcachon (Gironde).
# 		  44 La Pinasse. A Br.
# 		  45 La Plage d'Arcachon. Ch.
# 	      BINDER MESTRO (Madame).
# 	      P. C. P. 7, rue d'Artois, Paris.
# 		  46 Les Deux Sœurs.
# 		  47 Madone.
# 		  48 Lecture.
# 		  49 Prière.
# 		  50 Profil.
# 	      BLAND (W.-R.).
# 	      Duffield, Derby (Angleterre).
# 		  51 Le Pic de Derbyshire. Paysage. Pl. Dm.
# 	      BOBIR (N. de).
# 	       SOC. DAGUERRE.
# 		  21-1, rue Triochsviatitelskaj Kiew (Russie).
# 		  52 Coucher de Soleil.
# 	cat_pcp_1902.pdf_page_15.xml traité
# 8 – Traitement de cat_pcp_1902.pdf_page_16.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BOCA (Edmond).
# 	       SOC. CAENNAISE PH. Le Belvédère, Caen (Calvados).
# 		  53 Les Oies. A. Br.
# 	      BODEN (Evelyn).
# 	      The Friary, Derby (Angleterre).
# 		  54 Madame Gisborne et ses enfants. Pl.
# 		  55 La Répétition. Pl.
# 		  56 “ Flouted ”. Pl.
# 	      BOEL.
# 	       C. EFF. Bruxelles.
# 		  57 Les Foins. Br.
# 	      BOISSONNAS (F.).
# 	      Quai de la Poste, Genève.
# 		  58 Portrait de M. Janssen. D. Ch.
# 	      BOIVIN (Mme André).
# 	      64, rue de Lisbonne, Paris.
# 		  59 Faneuses. D. Pl.
# 		  60 La Rabette. D. Pl.
# 		  61 Forêt de Rambouillet. D. Pl.
# 	cat_pcp_1902.pdf_page_16.xml traité
# 9 – Traitement de cat_pcp_1902.pdf_page_17.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BOSSU (G.).
# 	      10, rue Madame, Paris.
# 		  62 Contre-jour sous bois. A. Br.
# 	      BOURGEOIS (Paul).
# 	       P. C. P. - S. A. E. 80, boulevard Malesherbes, Paris.
# 		  63 Effet de soir, Inverness.
# 		  64 La Rade d'Oban. Écosse.
# 	      BOUTIQUE (Augustin).
# 	       SOC. DU NORD DE LA FRANCE. 24, rue Saint- Thomas, Douai (Nord).
# 		  65 Départ du Troupeau. A. Br.
# 	      BOUY (Georges).
# 	      3, rue des Œillets, Bruxelles.
# 		  66 Brouillard en Condraz. A. Br.
# 	      BOUY (Jules).
# 	       C. EFF. 10, rue Charles, Bruxelles.
# 		  67 Aumatin. Br.
# 	cat_pcp_1902.pdf_page_17.xml traité
# 10 – Traitement de cat_pcp_1902.pdf_page_18.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BOVIER (L.).
# 	       C. EFF. 38, rue des Visitandines, Bruxelles.
# 		  68 Avant le Salut. G. B.
# 		  69 Joli Mai. G. B.
# 		  70 Éveil de Printemps. G. B.
# 		  71 Un Soir de Juin. Pl.
# 	      BROWN (E.-L.).
# 	      6, South, Clerk Street, Edimbourg (Écosse).
# 		  72 Dans le Bois.
# 		  73 A l'Ombre. Pl. S.
# 		  74 Reviendra-t-il.
# 	      BUCQUET (Mlle A.).
# 	       P. C. P. 12, rue Paul-Baudry, Paris.
# 		  75 Sur le Chemin.
# 		  76 L’Amstel.
# 	      BUCQUET (Maurice).
# 	       P. C. P. - S. A. E. - S. F. P. - L. R. - S. V. P. 12, rue Paul-Baudry, Paris.
# 		  77 Dans la Cité. Carcassonne.
# 		  78 Moisson en Savoie.
# 		  79 Portrait de M. P. Blanchard.
# 		  80 Brume du Matin.
# 		  81 Étude.
# 	cat_pcp_1902.pdf_page_18.xml traité
# 11 – Traitement de cat_pcp_1902.pdf_page_19.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      BUFFIÈRES (Comte de).
# 	       P. C. P. 29, rue de Bassano, Paris.
# 		  82 Le Pont d'Ainay, à Lyon. A. Br.
# 	      CADBY (Mme Carine).
# 	       L. R. Platt Boro Green, Kent (Angleterre).
# 		  83 Pavots.
# 		  84 Une Silhouette.
# 		  85 Nasturtiums.
# 	      CADBY (W.-A.).
# 	       L. R. Platt Boro Green, Kent (Angleterre).
# 		  86 Cour de Ferme.
# 		  87 Le Bois.
# 		  88 Étude de tête.
# 	      CAMUS (Victor).
# 	       P. C. P. Morlaix (Finistère).
# 		  89 Les Bords du Goyen-Pont-Croix. D. Ch. Fr.
# 		  90 Vallée de Saint-Jean-du-Doigt. A. Ch. Fr.
# 		  91 Morlaix, le Port. A. Ch. Fr.
# 		  92 En Décembre, Morlaix. D. Br.
# 	      CANFYN (Albert).
# 	       A. B. DE PH. 3, place du Lion d'Or, Gand (Bel¬ gique).
# 		  93 Providence des pêcheurs. A. Br.
# 		  94 Ferme flamande. A. Br.
# 		  95 Soir de Novembre. A. Br.
# 	cat_pcp_1902.pdf_page_19.xml traité
# 12 – Traitement de cat_pcp_1902.pdf_page_20.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      CANOVAS (Antonio).
# 	      Almagro, 12, Madrid.
# 		  96 Message d'Amour. D. G. cl.
# 		  97 En Grèce. D. G. cl.
# 		  98 La Prière. D. G. cl.
# 	      CASIER (Jos.).
# 	       A. B. DE PH. - P. C. P. 91, rue des Rémouleurs, Gand (Bel¬ gique).
# 		  99. Soir d'Automne à la mer.
# 		  100 Au parc de S'Gravenwesel.
# 	      CATALANO (Comte M. de).
# 	      1, rue Marchetti, Marseille.
# 		  101 Matinée brumeuse sur le Bosphore. A. Ch.
# 		  102 Crépuscule dans le golfe d'lsmidt. A. Ch.
# 	      CAVANIET (Louis).
# 	      168, rue Lafayette, Paris.
# 		  103 La Lettre. Br.
# 	      CHARPENTIER (Paul).
# 	      11, quai Conti, Paris.
# 		  104 Lever de soleil sur le lac Leman. A. Br.
# 		  105 Coucher de soleil sur le lac des 4 Cantons A. Br.
# 	cat_pcp_1902.pdf_page_20.xml traité
# 13 – Traitement de cat_pcp_1902.pdf_page_21.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_21.xml traité
# 14 – Traitement de cat_pcp_1902.pdf_page_22.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      CHARPENTIER (Hector).
# 	      51, rue Henri Kolb, Lille (Nord).
# 		  106 Flots du soir.
# 		  107 Sur la Plage de Katwyck.
# 		  108 Laura.
# 	      CHASTELLAIN (L.).
# 	      Place Saint-Laurent, Lausanne (Suisse).
# 		  109 Soleil couchant. A.
# 	      CHÉRI ROUSSEAU (G.).
# 	      3, rue de la Paix, Saint-Étienne (Loire).
# 		  110 Paysage. Effet de neige. D. Ch.
# 		  111 Paysage, Cerisiers en fleurs. D. Ch.
# 	      CHOISEUL. PRASLIN (Marq. de).
# 	      P. C. P. 54, avenue Marceau, Paris.
# 		  112 Coucher de soleil. Lucerne. A.
# 		  113 Tanger. A.
# 		  114 Reflets. Étude. A. Ch.
# 	      CLELAND (Georges).
# 	      61, Leith Walk, Leith, (Écosse).
# 		  115 Juin. Pl.
# 		  116 Inquiétude. Ch.
# 	cat_pcp_1902.pdf_page_22.xml traité
# 15 – Traitement de cat_pcp_1902.pdf_page_23.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      CLÉMENT (Dr E.).
# 	       P. C. P. - SOC. MALOUINE ET SERVANNAISE. Saint-Servan (Ille-et-Vilaine).
# 		  117 Essai d'éventail. Ch. Fr.
# 		  118 Avril. Ch. Fr.
# 		  119 Près du poële. Ch. Fr.
# 	      CLUGNY (Comte de).
# 	      6, rue Leroux, Paris.
# 		  120 Langueur. Ch.
# 		  121 Tête 1845. D. Ch.
# 	      CLUGNY (Marquis de).
# 	      6, rue Leroux, Paris.
# 		  122 Marché de Milly. A. Ch.
# 	      COEVOET (J.).
# 	      53, rue Emmery, Dunkerque (Nord).
# 		  123 Coucher de soleil. Gb.
# 		  124 Crépuscule au port. Gb.
# 	      COHEN (S.).
# 	      84, Utrechtschestraat, Amsterdam.
# 		  125 Cygnes. Br.
# 		  126 Brebis. Br.
# 	cat_pcp_1902.pdf_page_23.xml traité
# 16 – Traitement de cat_pcp_1902.pdf_page_24.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      COLLINS (Miss Essie).
# 	      Colombus, Ohio (U. S. A.).
# 		  127 Ophélie. D. Pl.
# 	      COQUET (E.).
# 	      Nonancourt (Eure).
# 		  128 Effet de neige.
# 	      COSTE (Ferdinand).
# 	       P. C. P. Lacanche, par Arnay-le-Duc (Côte- d'Or).
# 		  129 Portrait.
# 	      COUDELOU.
# 	       SOC. DES AMAT. DE PARIS. 55, rue du Château-d'Eau, Paris.
# 		  130 Reflets.
# 	      CRAIG A
# 	      NNAN. L. R. 230, Sauchiehall Street, Glasgow (Écosse).
# 		  131 Portrait de M. Holland Day. A. Ch.
# 		  132 Portrait du Professeur Young. A. Ch.
# 	cat_pcp_1902.pdf_page_24.xml traité
# 17 – Traitement de cat_pcp_1902.pdf_page_25.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      CRAIGIE (Reginald).
# 	       L. R. Camera-Club, Charing Cross road, Londres.
# 		  133 Étude de valeurs. Pl.
# 	      CROALL (W.-J.).
# 	      18, St. Albans Road, Édimbourg (Écosse).
# 		  134 Bull Dogs. A. Ch.
# 		  135 Qui appelle ? Pl.
# 	      CROOKE (W.).
# 	       L. R. 103, Princes Street, Edimbourg (Écosse).
# 		  136 Portrait de sir Noel Paton. R. S. A.
# 	      CLUGNIÈRES (Eugène).
# 	      59, rue de Gisors, Pontoise (Seine-et- Oise).
# 		  137 Vers l'École. A. Ch. Fr.
# 		  138 Nature morte. D. Gb.
# 	      DA CUNHA (A.).
# 	       P. C. P. 3, rue Meissonier, Paris.
# 		  139 Avant les régates. Ch.
# 		  140 Un pauvre diable. Br.
# 		  141 Temps de grève.
# 	cat_pcp_1902.pdf_page_25.xml traité
# 18 – Traitement de cat_pcp_1902.pdf_page_26.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      DARDONVILLE (Louis).
# 	       P. C. P. - S. A. E. 15, Chaussée de la Muette, Paris.
# 		  142 Relai de Chasse. A. Ch.
# 		  143 La Falaise. A. Ch.
# 		  144 Un Ruisseau. A. Ch.
# 	      DARNIS (A.).
# 	       P. C. P. - S. A. E. 4, rue Marbeuf, Paris.
# 		  145 Paysanne du Poitou. D. Ch. Fr.
# 		  146 Premières fleurs. D. Ch.
# 	      DAVIS (Henry-E.).
# 	      Camera-Club, Charing Cross road Londres (Angleterre).
# 		  147 Lune d'été.
# 	      DAVISON (Georges).
# 	       L. R. Beechcroft, the Park, East Molesey. (Angleterre).
# 		  148 L'Arbre aux longs bras.
# 		  149 Portrait au soleil.
# 		  150 La Porte ouverte.
# 		  151 Un Village dans les South Downs.
# 		  152 La Promenade.
# 	cat_pcp_1902.pdf_page_26.xml traité
# 19 – Traitement de cat_pcp_1902.pdf_page_27.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      DAY (HOLLAND).
# 	      9, Pinckney Street, Boston (U. S. A.).
# 		  153 L'Élève favori. Pl.
# 		  154 Le Déjeuner. Blidah. Pl.
# 		  155 Chef Éthiopien. Pl.
# 		  156 Le Masseur au bain Maure. Pl.
# 		  157 Rue d'Alger. Pl. Gb.
# 	      DELACRE (Pierre).
# 	      Vilvorde (Belgique).
# 		  158 Moutons.
# 		  159 Attelage à cinq.
# 	      DELPECH (E.).
# 	       P. C. P. 41, rue de Villiers, Neuilly (Seine).
# 		  160 Portraits de M. H. R. - A. Gb.
# 		  161 Portrait de M. G. I. - D. Gb.
# 	      DEMACHY (Robert).
# 	       P. C. P. - L. R. 13, rue Francois 1er, Paris
# 		  162 Portrait de madame R. D.- D. Gb.
# 		  163 Paysage d'Automne. A. Gb.
# 		  164 Danseuse. D. Gb.
# 		  165 Portrait. D. Gb.
# 		  166 Étude. D. Gb.
# 		  167 Tête d'Expression. D. Gb.
# 	cat_pcp_1902.pdf_page_27.xml traité
# 20 – Traitement de cat_pcp_1902.pdf_page_28.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      DETAILLE (F.).
# 	      21, rue de Noailles, Marseille (Bouches-du-Rhône).
# 		  168 Le Petit Saint-Jean. D. Ch.
# 		  169 Les Cygnes. D. Ch.
# 	      DEWIT (Ch.).
# 	       C. EFF. 27, rue Le Corrège, Bruxelles (Bel¬ gique).
# 		  170 Un Érudit. Ch.
# 		  171 La Causette. Pl.
# 	      DROUET.
# 	       S. F. P. - S. A. E. 107, boulevard Malesherbes, Paris.
# 		  172 Forêt de Compiègne. A. Br.
# 		  173 Sur les Quais. A. Br.
# 	      DUBREUIL (Pierre).
# 	       S. P. DE LILLE. 27, rue d'Angleterre, Lille (Nord).
# 		  174 Les Quilles. Ch. V.
# 		  175 Portrait d'un peintre. Gb.
# 		  176 Les Bulles. Ch. V.
# 		  177 Tête d'enfant. Gb.
# 		  178 Le Benedicite. Gb.
# 	cat_pcp_1902.pdf_page_28.xml traité
# 21 – Traitement de cat_pcp_1902.pdf_page_29.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      DUCOURAU (E.).
# 	       P. C. P. 104, boulevard Haussmann, Paris.
# 		  179 Fontaine à Sequeito. Espagne. A. Ch.
# 		  180 Moutons de Sare (Basses-Pyrénées). A. Ch.
# 		  181 Troupeau d'Aulette. A. Ch.
# 		  182 Paysage (Bidassoa). A. Ch.
# 	      DUPONT (Roger).
# 	      4, boulevard Lundy, Reims (Marne).
# 		  183 Étude. A. Ch.
# 	      DUVAL (R.).
# 	       P. C. DE ROUEN. 12, rue François-Arago, Rouen (Seine- Inférieure).
# 		  184 Le Vieux Moulin.
# 		  185 Crépuscule au Havre.
# 	      EARLE (Morris).
# 	      1918, Spruce Street, Philadelphie (U. S. A.).
# 		  186 Carmita. A.
# 	      ECALLE G.-C.).
# 	      8, rue de l'Arcade, Paris.
# 		  187 Profil de Médaille. D. Ch. Fr.
# 		  188 Sous les Fleurs. D. Ch. Fr.
# 		  189 Au Maroc. D. Ch. Fr.
# 		  190 Jeune Fille au Stick. D. Ch. Fr.
# 	cat_pcp_1902.pdf_page_29.xml traité
# 22 – Traitement de cat_pcp_1902.pdf_page_30.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_30.xml traité
# 23 – Traitement de cat_pcp_1902.pdf_page_31.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      FAUCHIER MAGNAN (A.).
# 	       P. C. P. 45, boulevard Haussmann, Paris.
# 		  191 Vue de Hollande. A. Br.
# 		  192 Vue de Hollande. A. Br.
# 		  193 Dans l'île de Marken. A. Br.
# 	      FERRAND (H.).
# 	      50, rue Victor-Hugo, Bois-Colombes (Seine).
# 		  194 Marie-Anne. D. Ch. Fr.
# 		  195 Étude. D. Ch. V.
# 		  196 Portrait. D. Ch. V.
# 		  197 A la Cuisine. D. Ch. V.
# 	      FERRAND (Stanislas).
# 	      50, rue Victor-Hugo, Bois-Colombes, (Seine).
# 		  198 Méditation. D. Ch. Fr.
# 	      FINEL (G.).
# 	      53, rue du Midi, Taverny, (Seine-et- Oise).
# 		  199 Le Chemin de l'Étable. A. Ch.
#
# 	      2.
# 		  2.
# 	cat_pcp_1902.pdf_page_31.xml traité
# 24 – Traitement de cat_pcp_1902.pdf_page_32.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      FISCHER (N.).
# 	      Stengade, Copenhague (Danemark).
# 		  200 Le Far West danois. Ch.
# 		  201 Portrait de mon Père. Ch.
# 		  202 Minuit. Ch.
# 		  203 Clair de lune. Ch.
# 		  204 Sainte Cécile. Ch.
# 	      FLAMM (Docteur R.).
# 	       P. C. P. 39, avenue Marceau, Paris.
# 		  205 Portrait de mademoiselle Th. B. - D. Ch. Fr.
# 		  206 Portrait de M. S. W. - D. Ch. Fr.
# 		  207 Méditation. D. Ch. Fr.
# 		  208 Cenza. D. Ch. Fr.
# 		  209 Arlequin. D. Ch. Fr.
# 		  220 Le Calvaire. D. Ch. Fr.
# 	      FONDU (Charles).
# 	       C. EFF. Vilvorde-lez-Bruxelles (Belgique).
# 		  211 Sœur Madeleine. Gb.
# 		  212 L'Organiste. Br.
# 		  213 Menaces d'Orage. Ch.
# 	      FONSECA (Arnoldo).
# 	      19, rua Luz Soriano, Lisbonne (Portugal).
# 		  214 Vieux temps. D. Pl.
# 		  215 Portrait commencé. D. Gb.
# 	cat_pcp_1902.pdf_page_32.xml traité
# 25 – Traitement de cat_pcp_1902.pdf_page_33.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      FOULIS.
# 	      27, Cluny Gardens, Edimbourg (Ecosse).
# 		  216 Le Matin. Ch.
# 		  217 Le Berger. Br.
# 	      FREDERIKSEN (Carl).
# 	      Nowevoldgade, 96, Copenhague (Dane¬ mark).
# 		  218 Novembre. Pl.
# 	      GANDON (Mlle M.).
# 	      10, rue du Palais, Carcassonne (Aude).
# 		  219 La Cité par temps de neige. A. Br.
# 	      GARCZYNSKI.
# 	      34, rue du Pavé, Le Mans (Sarthe).
# 		  220 Distraction. D. Br.
# 		  221 Sous la Lampe. A. Br.
# 		  222 Dans la Caye. A. Br.
# 	      GASPAR (Ch.).
# 	       C. EFF. 16, rue de Virton, Arlon (Belgique).
# 		  223 Portrait. Br.
# 		  224 Portrait. Pl.
# 		  225 En Hiver. Pl.
# 	cat_pcp_1902.pdf_page_33.xml traité
# 26 – Traitement de cat_pcp_1902.pdf_page_34.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      GEERTS (Jules).
# 	       C. EFF. 168, boulevard Anspach, Bruxelles.
# 		  226 Pâturage. Gb.
# 	      GIBORY (A.).
# 	      36, rue des Petits-Champs, Paris.
# 		  227 Portrait. D. Ch. V.
# 	      GILIBERT (A.).
# 	       S. A. E. - P. C. P. 55, rue de Prony, Paris.
# 		  228 Marine. A. Ch.
# 		  229 Revenant de la Fontaine. A. Ch. Fr.
# 		  230 Une Boucherie à Louviers. A. Br.
# 		  231 Un Paludier de Saillé. A. Ch. Fr.
# 		  232 Le Soir aux étangs de Cernay. A. Br.
# 	      GILLET(Fernand).
# 	       S. A. E.- S. F. P. - P. C. P. 47, rue Jacob, Paris.
# 		  233 Rêverie. A. Ch. Fr.
# 	      GLEASON (Arthur-A.).
# 	      52, Vernon Street Dedham, Mass. (U. S A.)
# 		  234 Maternié. Pl.
# 		  235 L'Étang. Pl.
# 		  236 Paysage d’Hiver. Pl.
# 		  237 Avril. Pl.
# 	cat_pcp_1902.pdf_page_34.xml traité
# 27 – Traitement de cat_pcp_1902.pdf_page_35.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_35.xml traité
# 28 – Traitement de cat_pcp_1902.pdf_page_36.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      GOMEZ GIMENO (Alfredo).
# 	      7, rue Lafaurie-de-Montbadon, Bor¬ deaux.
# 		  238 Port de Royan. D. Ch. Fr.
# 		  239 Port de Royan. D. Ch. Fr.
# 		  240 En-tête pour Carte-lettre. D. Ch. Fr.
# 	      GOSSIN (E.).
# 	      14, rue du Faubourg Saint-Honoré, Paris.
# 		  241 Sous-bois (Compiègne). D. Ch.
# 	      GOUDCHAUX (Henri).
# 	       P. C. P. 6, rue Boissy d'Anglas, Paris.
# 		  242 A Vevey.
# 	      GOUNST (A.).
# 	      Starokoniouchenny, Maison Gounst, Moscou.
# 		  243 Étude. Ch.
# 	      GOUSSEAU (Abel).
# 	      Saint-Laurent-sur-Sèvre (Vendée).
# 		  244 A L'Abreuvoir, étude de soir. D. Br.
# 	cat_pcp_1902.pdf_page_36.xml traité
# 29 – Traitement de cat_pcp_1902.pdf_page_37.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      GRAHL (Mademoiselle.)
# 	      33, Burgerwiese, Dresde (Allemagne).
# 		  245 Automne. D.
# 		  246 Frère et Sœur. D.
# 		  247 Enfant. D.
# 		  248 Jeunesse. D.
# 	      GRAS (Henri).
# 	       S. F. P. 52, Boulevard Ménilmontant, Paris.
# 		  249 Château de Chillon. A. Ch. V.
# 		  250 Coup de Mer à Villers. A. Ch. V.
# 	      GRIMPREL (Georges).
# 	       P. C. P. 71, rue du Faubourg-Saint-Honoré, Paris.
# 		  251 "Aïcha". Gb.
# 		  252 Fenêtre d'Atelier. Gb.
# 		  253 Étude. Gb.
# 		  254 Médaillon. Gb.
# 		  255 Sanguine. Gb.
# 	      GUÉRIN (Henri).
# 	       P. C. P. - S. A. E. 21, rue du général Foy, Paris.
# 		  256 Brume.
# 		  257 Brouillard en Seine.
# 	cat_pcp_1902.pdf_page_37.xml traité
# 30 – Traitement de cat_pcp_1902.pdf_page_38.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      GUGGENHEIM (Albert).
# 	       C. EFF. 3, rue de Lombardie, Bruxelles (Belgique).
# 		  258 Portrait du peintre Hans Christiansen. Pl.
# 		  259 Portrait.
# 	      HAAREN (Van).
# 	      Arnheim (Hollande).
# 		  260 Procesion dans le village. A.
# 	      HÉGOT (Fernand).
# 	      5, rue de la Paix, PAris.
# 		  261 Bords de l'Yvette. D. Ch.
# 	      HÉLAIN (A.).
# 	       S. F. P. 2, rue Grétry, Paris.
# 		  262 Lavoir en Bretagne. A. Ch.
# 		  263 Soleil et Nuages. A. Ch.
# 		  264 Pseudo-Clair de lune. A. Ch.
# 	      HELLOUIN D
# 	      E MENIBUS. S.F. P. 5, rue Sainte-Beuve, Paris.
# 		  265 Dans la Buanderie. D. Ch. Fr.
# 		  266 Bonne Maman. D. Ch. Fr.
# 	cat_pcp_1902.pdf_page_38.xml traité
# 31 – Traitement de cat_pcp_1902.pdf_page_39.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      HERVÉ (Lucien).
# 	       S. A. E. 71, rue Raynouard.
# 		  267 Champigny-Saint-Marne. D.
# 	      HORSLEY HINTON (A.).
# 	       L. R. 52, Long Acre, Londres (Angleterre).
# 		  268 “ Recessional ”. A. Pl.
# 		  269 Vers les Collines. A. Pl.
# 		  270 Les Dunes. A. Pl.
# 	      HUDSON C
# 	      HAPMANN. 1128, Spruce Street, Philadelphie (U. S. A.)
# 		  271 Au Réfectoire.
# 	      HUGUET (Mme A.).
# 	       P. C. P. 146, avenue des Champs-Élysées, Paris.
# 		  272 La Lettre. A. Br.
# 		  273 Étude de Contre-jour. A. Ch. V.
# 		  274 Pâturage. A. Ch. Fr.
# 		  275 Le Soir. Rentrée à la ferme. A. Br.
# 	      HUILLARD (Ernest).
# 	       S. F. P.- S. A. E. 5, rue du 29 Juillet, Paris.
# 		  276 La Mare aux Fées. D. Ch. V.
# 		  277 Les Saules. D. Ch. V.
# 	cat_pcp_1902.pdf_page_39.xml traité
# 32 – Traitement de cat_pcp_1902.pdf_page_40.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_40.xml traité
# 33 – Traitement de cat_pcp_1902.pdf_page_41.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      HUILLIER (A.).
# 	       P. C. P. 83, boulevard Haussmann, Paris.
# 		  278 Les Chênes. A. Ch. V.
# 		  279 Café Maure. A. Ch. V.
# 	      IMBERT (Léonce).
# 	      5, place de la Bourse, Marseille (Bouches-du-Rhône).
# 		  280 Quiétude du Soir. A. Ch.
# 		  281 Aube naissante. D. Ch.
# 	      JACQUEMONT (H.).
# 	      1, rue de Beaune, Paris.
# 		  282 Lecture à vue. A. Br.
# 	      JOB (Charles).
# 	      High Lands, The Drive Hove, Sussex, (Angleterre).
# 		  283 Retour du Toupeau. Ch.
# 	      JOLY (Jacques de).
# 	       S. E. P. 34, rue de Tocqueville, Paris.
# 		  284 Le Tricot de Grand'Mère. D. Ch.
# 	cat_pcp_1902.pdf_page_41.xml traité
# 34 – Traitement de cat_pcp_1902.pdf_page_42.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      HUBERT (Émile).
# 	       P. C. P. 138, boulevard Haussmann, Paris.
# 		  285 Paysage Normand. A. Ch. V.
# 	      KAPTEYN (Alb.).
# 	       P. C. P. 11, Kurhausstrasse, Zurich (Suisse).
# 		  286 Université de Glasgow dans le Brouillard. A. Br.
# 		  287 Inondation. D. Pl.
# 		  288 Tête de Fillette. A. Pl.
# 		  289 Portrait. D. Pl.
# 	      KÄSEBIER (Mme Gertrude).
# 	       L. R.
# 		  3 W. 29me rue, New-York (U. S. A.).
# 		  290 Homme au Chapeau. Pl.
# 		  291 Cathryne. Gb.
# 		  292 Portrait de M. Clarence White. Gb.
# 		  293 Au lever du Soleil. Gb.
# 		  294 Portrait de M. Frédéric Evans. Gb.
# 		  295 La Mariée. Gb.
# 	      KLEINTJES (L.-L.).
# 	      17, rue de Suisse, Bruxelles.
# 		  296 Soins du ménage. Ch.
# 		  297 Près du Berceau. Ch.
# 		  298 Avant l'orage. A. Br.
# 	cat_pcp_1902.pdf_page_42.xml traité
# 35 – Traitement de cat_pcp_1902.pdf_page_43.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      KOURLINE (A.).
# 	      Samara (Russie).
# 		  299 Tempête sur la mer Noire. Ch.
# 		  300 Dans la Carrière. Pl.
# 	      KRAFFT (Hugues).
# 	       P. C. P. 42, rue de Lubeck, Paris.
# 		  301 Portai lde Chah-Zindé, à Samarkand. A. Ch.
# 		  302 Une Juive de Samarkand. A. Ch.
# 		  303 Le ravin de Siab (Turkestan Russe). A. Ch.
# 		  304 Le Torrent à Ourgout (Turkertan Russe). A. Ch.
# 	      LABAT (Louis).
# 	      26, rue de la Salie, Bayonne (Basses- Pyrénées).
# 		  305 Les Joncs. Gb.
# 		  306 Portrait de M. Herrel. Gb.
# 	      LACLOS (Albert de).
# 	      16, rue du Pré-aux-Clercs, Paris.
# 		  307 Bords de rivière. D. Ch. Fr.
# 	cat_pcp_1902.pdf_page_43.xml traité
# 36 – Traitement de cat_pcp_1902.pdf_page_44.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      LAGUARDE (Mlle C.).
# 	       P. C. P. Villa des Pins, Aix-en-Provence.
# 		  308 La Mèche Blonde. Gb.
# 		  309 Étude. B. B.
# 		  310 Figure allégorique du Printemps. Gb.
# 		  311 Enfant de chœur. Gb.
# 		  312 Les Petits Bonnets. Gb.
# 	      LAILLER (M.).
# 	      86, rue de Miromesnil, Paris.
# 		  313 Après la Moisson. D. Ch. Fr.
# 		  314 La Hutte au bois. D. Ch. Fr.
# 		  315 Temps d’Automne. A. Gb.
# 	      LANGDON COBURN (Alvin).
# 	      827, Boylston Street, Boston (U. S. A.).
# 		  316 Le Stryge. Notre-Dame. Pl.
# 		  317 Bords de rivière. Pl.
# 		  318 L'Auberge. Pl.
# 	      LANGLOIS (Maurice).
# 	       S. V. P. - S. A. E. 15, rue Hoche, Versailles (Seine-et- Oise).
# 		  319 Marine. A. Vu.
# 	cat_pcp_1902.pdf_page_44.xml traité
# 37 – Traitement de cat_pcp_1902.pdf_page_45.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      LANGOIT (F.).
# 		  23 bis, avenue Niel, Paris.
# 		  320 “ Dédette ”. Portrait. D. Gb.
# 	      LASSENCE (Mme Ch. de).
# 	      Le Chalet, Petit-Boulevard, Pau (Basses-Pyrénées).
# 		  321 Étude d'enfant. D. Ch.
# 	      LE BÈGUE (René).
# 	       P. C. P. 51, rue Le Peletier, Paris.
# 		  322 Esquisse. Br.
# 		  323 Étude pour une enseigne. Gb.
# 		  324 Femme drapée. Gb.
# 		  325 Éventail. Ch.
# 	      LEDARD (René).
# 	       P. C. P. 37, rue Godot-de-Mauroy, Paris.
# 		  326 Portrait de Madame R.
# 		  327 Marine.
# 		  328 Sous les Grands Arbres.
# 		  329 Inondation sur les bords de la Loire.
# 		  330 Matinée d'Automne.
# 	cat_pcp_1902.pdf_page_45.xml traité
# 38 – Traitement de cat_pcp_1902.pdf_page_46.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      LE ROUX (Paul).
# 	       P. C. P. - S. A. E. 48, boulevard Malesherbes, Paris.
# 		  331 Près de la Roche-Guyon.
# 		  332 Sur le Lay (Vendée).
# 		  333 Marais mouillés (Vendée).
# 	      LESTRANGE (Comte de).
# 	       P. C. P. - S. A. E. 43, avenue Montaigne, Paris.
# 		  334 Sur la Seine. S.
# 		  335 Feuilles mortes à Trianon. Ch. V.
# 	      LEYS (F.).
# 	       C. EFF. 26, rue Ernest-Allard (Bruxelles).
# 		  336 Pauvre Bourg. Gb.
# 		  337 L'Heure de l'Office. Gb.
# 		  338 Via Serbelloni. Ch.
# 		  339 La Rentrée. Ch.
# 		  340 Profil. Pl.
# 	      LOUP (Capitaine du).
# 	      93, rue de Prony, Paris.
# 		  341 Cascades du Cydnus. A. Br.
# 	      MABIRE (Edmond).
# 	      6, rue de Madrid, Paris.
# 		  342 Portrait de M. B. A. Br.
# 	cat_pcp_1902.pdf_page_46.xml traité
# 39 – Traitement de cat_pcp_1902.pdf_page_47.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      MAHY.
# 	       C. EFF. Bruxelles.
# 		  343 Neiges. Gb.
# 		  344 Moutons. Gb.
# 	      MALLET (H.).
# 	      Villa Jeanne, Nice-Baumettes (Alves- Maritimes).
# 		  345 Port de Marseille. A. B.
# 		  346 Coucher de Soleil à Boulogne-sur-Mer. A. B.
# 	      MALOFF CHRYSOPRAZE (M.).
# 	      134, boulevard du Montparnasse, Paris.
# 		  347 Par un Soir de Gros Temps. A. Ch. Fr.
# 		  348 Clair de Lune. A. Ch. Fr.
# 	      MANNHEIM (J.).
# 	       P. C. P. 7, rue Saint-Georges, Paris.
# 		  349 Étude. D. Pl.
# 	      MANWARING (E.-E.).
# 	      Holmbury St.-Botolph's road, Wor¬ thing (Angleterre).
# 		  350 Port de Dieppe. A. Br.
# 	cat_pcp_1902.pdf_page_47.xml traité
# 40 – Traitement de cat_pcp_1902.pdf_page_48.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      MARCHANT (Mlle P.).
# 	      12, rue de Lorraine, Saint-Germain-en- Laye (Seine-et-Oise).
# 		  351 Étude. D. Ch. Fr.
# 	      MARCHEVILLE (L. de).
# 	       P. C. P. 138, boulevard Hau smann, Paris.
# 		  352 Portrait. Ch.
# 	      MARGUERY (A.).
# 	      1, avenue Carnot, Deville-lès-Rouen (Seine-Inférieure).
# 		  353 Matinée de Dégel. D. Ch. Fr.
# 	      MARTINET (H.).
# 	      39, rue de L'Ouest, Courbevoie (Seine).
# 		  354 Soir d'hiyer à Pau. A. Br.
# 	      MASSION (Mlle A.).
# 	      58, boulevard Haussmann, Paris.
# 		  355 Petit Canal à Venise. A. Br.
# 		  356 Le Vicomté à Dinard. A. Br.
# 	cat_pcp_1902.pdf_page_48.xml traité
# 41 – Traitement de cat_pcp_1902.pdf_page_49.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_49.xml traité
# 42 – Traitement de cat_pcp_1902.pdf_page_50.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      MATHY (Capitaine R.).
# 	       C. EFF. 41, rue Wény, Ixelles-Bruxelles.
# 		  357 Étude. Gb.
# 		  358 Captive. Br.
# 		  359 Pensée. Br.
# 	      MAUPEOU (Vte A. de).
# 	       P. C. P. - S. A. E. 4, rue de La Baume, Paris.
# 		  360 Sous la neige. A. Br.
# 		  361 Sous la neige. A. Br.
# 		  362 Sous la neige. A. Br.
# 	      MEYER HEIN (H.).
# 	      16, rue Brémontier, Paris.
# 		  363 L'Hiver. A. Ch. Fr.
# 	      MICHELIS (Fernand).
# 	      Palais de la Bourse (Marseille).
# 		  364 Dans le Port. A. Ch.
# 		  365 Remorqueur. A. Ch.
# 		  366 Paysage d'Automne. A. Ch.
# 	      MISONNE (Léonard).
# 	       A. B. DE PH. Gilly (Belgique).
# 		  367 Hiver sur la Meuse.
# 		  368 Au Coucher du Soleil.
# 		  369 Hiver sur la Meuse.
# 		  370 Brume.
# 		  371 En passant.
# 	cat_pcp_1902.pdf_page_50.xml traité
# 43 – Traitement de cat_pcp_1902.pdf_page_51.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      MIZAEL DE PAS (Comte).
# 	      Rue Gauthier-de-Châtillon, Lille (Nord).
# 		  372 Profil perdu. Br.
# 		  373 Sybilla. Br.
# 	      MONS (Van).
# 	       C. EFF. Bruxelles.
# 		  374 Moutons et Brouillard. Gb.
# 		  375 Étang de Rouge-Cloître. Gb.
# 	      NIEDECKEN (Georges).
# 	      Milwankee (U. S. A.).
# 		  376 Dans les Roseaux. Pl.
# 		  377 Femme aux gants noirs. Pl.
# 		  378 Dans le Bois. Pl.
# 		  379 Femme lisant. Pl.
# 	      NORTH (H.-A.).
# 	      254, South 17th Street, Philadelphie.
# 		  380 Soir d'Opéra. Pl.
# 		  381 La Trinité à minuit. Pl.
# 	      OTTENHEIM (Léon).
# 	       S. V. P. - P. C. P. 73, rue Duplessis, Versailles (Seine- et-Oise).
# 		  382 Moutons. A. Br. Vu.
# 		  383 Le Mein, près Francfort. A. Br.
# 		  384 L'Elbe à Hambourg. A. Br.
# 	cat_pcp_1902.pdf_page_51.xml traité
# 44 – Traitement de cat_pcp_1902.pdf_page_52.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      PATERSON (Andrew).
# 	      32, Church Street, Inverness (Ecosse).
# 		  385 Portrait d'une jeune Dame. D. Br.
# 		  386 Ma Femme. D. Pl.
# 		  387 Prière du Soir. D. Pl.
# 	      PECTOR (S.).
# 	       S. F. P. - S. A. E. 9, rue Lincoln, Paris.
# 		  388 Moulin d'Habaurapt. A. Br.
# 		  389 Le Hœneik. A. Br.
# 	      PERSONNAZ (A.).
# 	       S. F. P.- S. A. E. 4, rue Sainte-Cécile, Pars.
# 		  390 Effet du Soir sur la mer. A. Ch.
# 		  391 Devant l’Esterel. A. Ch.
# 		  392 Labour. A. Ch.
# 	      PETIT(Charles).
# 	       P. C. P. 30, avenue de Messine, Paris.
# 		  393 A la foire de Montbran (Côtes-du-Nord). A. Ch.
# 		  394 A la foire de Montbran. A. Ch.
# 		  395 Bords d'Etang. A. Ch.
# 	      PETIT (Roger).
# 	      30, avenue de Messine, Paris.
# 		  396 Dans un Bar. A. Ch.
# 		  397 Pauvre Vieille. A. Ch.
# 		  398 En Hollande. A. Ch.
# 	cat_pcp_1902.pdf_page_52.xml traité
# 45 – Traitement de cat_pcp_1902.pdf_page_53.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      PONS (Jean).
# 	      25, cours Lieutaud, Marseille.
# 		  399 Après l'Orage. D. Ch.
# 		  400 Crépuscule. D. Ch.
# 	      PRIN D'ORIGNY (F.).
# 	       P. C. P. - S. A. E. 16, rue du Pré-aux-Clercs, Paris.
# 		  401 Portrait. Ch. Fr.
# 		  402 Brumes d'Automne. A. Pl.
# 		  403 Le Pont des Saints-Pères. A. Pl.
# 		  404 Matinée d'Octobre. D. Ch. Fr.
# 		  405 La Marne à Champigny. D. Br.
# 	      PROUST (Émile).
# 	      11, rue de Laroche, Saintes (Charente- Inférieure).
# 		  406 Château de Clisson. D. Ch. V.
# 	      PUYO (C.).
# 	       P. C. P. 5, avenue Dupuis, La Fère (Aisne).
# 		  407 Impression d'Automne. Ch. Fr.
# 		  408 Pommier en fleur. Ch. Fr.
# 		  409 Nymphe. Ch. Fr.
# 		  410 Octobre. Ch. Fr.
# 		  411 Le Ruisseau. Ch. Fr.
# 		  412 Étude. Ch. Fr.
# 	cat_pcp_1902.pdf_page_53.xml traité
# 46 – Traitement de cat_pcp_1902.pdf_page_54.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      QUENTIN (J.).
# 	      Sainte-Catherine-lez-Arras (Pas-de-Ca¬ lais).
# 		  413 Crépuscule d'Hiver. D.
# 		  414 Pour les Oiseaux. D.
# 	      REGAD (Albert).
# 	       P. C. P. - PH. CL. HAUT-JURA. 42, rue du Pré, Saint-Claude (Jura).
# 		  415 Impression d'Automne. A. Br.
# 		  416 Moutons à l'Alpage. A. Br.
# 		  417 Étang des Dombes. A. Br.
# 	      RISTON (Victor).
# 	       PRÉS. DE LA SOC. LORRAINE DE PHOTOGR. Malzéville, Nancy (Meurthe-et-Moselle).
# 		  418 A la Fontaine. A. G. Br.
# 		  419 Au Travail. A. G. Br.
# 	      RIV
# 	      É. 41, rue du Bel-Air, Le Mans (Sarthe).
# 		  420 Agnus.
# 	      ROCHAMBEAU (Comte de).
# 	      P. C. P. 56, avenue Victor-Hugo, Paris.
# 		  421 Coin de Foire. A. Br.
# 	cat_pcp_1902.pdf_page_54.xml traité
# 47 – Traitement de cat_pcp_1902.pdf_page_55.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      ROLATO-PETION (Paul).
# 	      45, boulevard du Midi, Le Vésinet (Seine-et-Oise).
# 		  422 Enfant. D. Ch.
# 		  423 Étude. D. Ch.
# 		  424 Invocation. D. Ch.
# 		  425 Fresque. D. Gb.
# 	      ROM (H.-N.).
# 	      Sykkesholms Alle A B, Copenhague (Danemark).
# 		  426 Automne. G. cl.
# 		  427 Sieste. Ch.
# 	      ROQUERBE (Gustave).
# 	       S. A. E. 238, faubourg Saint-Honoré, Paris.
# 		  428 Le Tricot. D.
# 		  429 Fileuse au repos. D. Br.
# 		  430 Poussière dorée. D. Br.
# 		  431 Des Chardons. D. Br.
# 	      ROUSSEAU (René).
# 	       A. B. DE PH. 11, rue des Riches-Claires, Ypres, (Belgique).
# 		  432 L'Angélus. A.
# 	cat_pcp_1902.pdf_page_55.xml traité
# 48 – Traitement de cat_pcp_1902.pdf_page_56.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      ROUZÉ (Paul).
# 	       A. PRAT. DE PH. LILLE - S. P. LILLE. 84, rue Brûle-Maison, Lille (Nord).
# 		  433 Troupeau de Moutons. A. Br.
# 	      ROY (Georges).
# 	       P. C. P. - S. A. E. - S. F. P. 145, boulevard Haussmann, Paris.
# 		  434 Bœufs à la Herse. A. Ch.
# 		  435 Au Bord de l'eau. A. Ch.
# 	      ROY (Mlle Madeleine).
# 	      145, boulevard Haussmann, Paris.
# 		  436 La petite Gitane. A. Ch.
# 	      RUYSSEN (H.).
# 	       C. EFF. Furnes (Belgique).
# 		  437 Étang. Br.
# 	      SACRÉ (Edmond).
# 	       A. B. DE PH. 1, rue de la Calandre, Gand (Belgique).
# 		  438 Vieux Moine au Bréviaire. D. Gb.
# 		  439 Brumes du Soir.
# 		  440 Crépuscule d'Hiver. D. Gb. Nature Hivernale. D. Gb.
# 	cat_pcp_1902.pdf_page_56.xml traité
# 49 – Traitement de cat_pcp_1902.pdf_page_57.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      SCHARF (Otto).
# 	       L. R. 139, Victoria strasse, Crefeld (Allemagne).
# 		  442 Le Ruisseau dans la Forêt.
# 		  443 Bord de Prairie.
# 		  444 Mère et Enfant.
# 	      SCHELCHER (André).
# 	      29, rue de la Bienfaisance, Paris.
# 		  445 “ Bonum vinum lœtificat ”.
# 	      SCOTT (Robert).
# 	      New Lynn St, Léonard road, Ayr (Écosse).
# 		  446 Étude de Tête. Al.
# 		  447 Portrait du Révérend W. Cavins. Pl. Dm.
# 	      SEIGNEURIE (Mme).
# 		  28 bis, rue Guillaume-Tell, Paris.
# 		  448 Légère Brise. A.
# 	      SIMON (Th.).
# 	      9, rue Clavel, Paris.
# 		  449 Coucher de Soleil à Kairouan. A. Br.
# 		  450 Oasis à Biskra. A. Br.
# 	cat_pcp_1902.pdf_page_57.xml traité
# 50 – Traitement de cat_pcp_1902.pdf_page_58.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_58.xml traité
# 51 – Traitement de cat_pcp_1902.pdf_page_59.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      SINGLY (P. de).
# 	       P. C. P. 89, boulevard Malesherbes, Paris.
# 		  451 Les Crémeaux à Meulan. D. Pl.
# 	      SNEYERS (L.).
# 	       C. EFF. Bruxelles.
# 		  452 Au Petit-jour. Gb.
# 		  453 Soleil de Mars. Gb.
# 		  454 Dame au Chapeau. Ch.
# 		  455 Dans le Brouillard. Pl.
# 		  456 La Herse. Gb.
# 	      SOLLET (Charles).
# 	       S. A. E. 1, rue Turbigo, Paris.
# 		  457 La Dame à l'Éventail. D. Gb.
# 		  458 Portrait. D. Gb.
# 		  459 Portrait de M. V.-D. Gb.
# 		  460 Aux Champs. D. Gb.
# 		  461 Étude en sanguine. D. Gb.
# 		  462 La Cuisinière. D. Gb.
# 	      SOUZY (A.).
# 	      28, boulevard Périer, Marseille.
# 		  463 Étude. D. Ch.
# 	      SQUEVILLE (Maurice).
# 	      15, rue Eugénie, Saint-Mandé (Seine).
# 		  464 Portrait d'Enfant. A.
# 	cat_pcp_1902.pdf_page_59.xml traité
# 52 – Traitement de cat_pcp_1902.pdf_page_60.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      STIEGLITZ (Alfred).
# 	       L. R.
# 		  3 W, 29me rue, New-York (U. S. A.).
# 		  465 Printemps.
# 		  466 Étude d'éclairage. D. Pl.
# 	      STOIBER (A.-H.).
# 	       P. C. P. 31, boulevard Haussmann, Paris.
# 		  467 Arc de Titus, à Rome. A. Ch.
# 		  468 En Provence. A. Br.
# 		  469 Approche de l'orage (Venise). A. Br.
# 	      STOUFFS (Victor).
# 	      277, avenue Louise, Bruxelles.
# 		  470 Brume d'Automne. A. Br.
# 		  471 Décembre. A. Gb.
# 		  472 La Tamise à Londres. A. Gb.
# 	      STUMM (J.).
# 	      20, rue d'Hauteville, Paris.
# 		  473 Étude. A. G. Cl.
# 	      TAPONIER (A.).
# 	      12, rue de la Paix, Paris.
# 		  474 Première Sortie. D.
# 		  475 Profil d'Enfant. D. Ch.
# 		  476 Un Rayon de soleil. D.
# 		  477 Portrait de M. de Feure. A.
# 		  478 Portrait en chapeau de Madame H. de D.-D. Ch.
# 	cat_pcp_1902.pdf_page_60.xml traité
# 53 – Traitement de cat_pcp_1902.pdf_page_61.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      TEIL DU HAVELT (Baron du).
# 	      P. C. P. 3, avenue d'Antin, Paris.
# 		  479 Rêverie.
# 		  480 Moutons au pâturage.
# 		  481 La Napoule.
# 	      THÉOPHILE-GAUTIER (Dr P.).
# 	      46, rue de la Bienfaisance, Paris.
# 		  482 Portrait de mademoiselle R. I.-D. Br.
# 		  483 Tête de Jeune Fille. D. Gb.
# 		  484 Iseult. D. Gb.
# 		  485 Étude. D. Gb.
# 		  486 A la fenêtre. D. Gb.
# 	      THOMSON (Robert).
# 	      66, Newington road, Édimbourg (Écosse).
# 		  487 Arrivée de la Mariée. Ch.
# 		  488 Bohémienne. Ch.
# 	      THORÉ (A. de).
# 	      Rue de la Sangle, Mantes (Seine- et-Oise).
# 		  489 La Lecture. D.
# 	cat_pcp_1902.pdf_page_61.xml traité
# 54 – Traitement de cat_pcp_1902.pdf_page_62.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      THURNEYSSEN (Émile).
# 	       P. C. P. 10, rue de Tilsitt, Paris.
# 		  490 Portraits de madame G. et de mademoiselle C. A. Br. Vu.
# 		  491 Bords de l'Oise, en Hiver. A. Br. Vu.
# 		  492 Jeanne d'Arc. A. Br. Vu.
# 		  493 Ruines de l'Abbaye d'Ourscamp (Oise). A. Br. Vu.
# 	      TOLLU (Camille).
# 	       P. C. P. 9, rue de Grenelle, Paris.
# 		  494 A Saint-Sec.
# 		  495 Le Portel.
# 		  496 Moutons à Pinceloup.
# 		  497 Boulogne-sur-mer. Futurs marins.
# 	      TOUCAS (Albert).
# 	       P. C. P. 29, boulevard des Batignolles, Paris.
# 		  498 Contre-jour. A. Ch.
# 	      TOURANCHET (Claudius).
# 	      6, rue Jouffroy, Paris.
# 		  499 Étude. D. Ch. Fr.
# 		  500 Étude. D. Ch. Fr.
# 	cat_pcp_1902.pdf_page_62.xml traité
# 55 – Traitement de cat_pcp_1902.pdf_page_63.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_63.xml traité
# 56 – Traitement de cat_pcp_1902.pdf_page_64.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      TYSZKIEWICZ (Comte B.).
# 	      P. C. P. - S. A. E.
# 		  2bis, rue Boccador, Paris.
# 		  501 Paysan japonais en costume de mauvais temps. A. Ch.
# 		  502 Pèlerin japonais. A. Ch.
# 		  503 La Fête des Cerisiers en fleurs à Tokio (21 avril). A. Ch.
# 		  504 Vieux Murs de Nankin. A. Ch.
# 		  505 Jonque de Guerre A. Ch.
# 	      UBELMANN (Robert).
# 	      7, boulevard Barbès, Paris
# 		  506 Soir sur le Leman. A. Br.
# 	      VALPINÇON (L.).
# 	       P. C. P. 79, boulevard Malesherbes, Paris.
# 		  507 Le Pâturage. A. Ch. V.
# 		  508 Trappistes allant au travail. A. Ch. V.
# 	      VERBEECK (Arthur).
# 	       C. EFF.
# 		  56 rue du Vanneau, Anvers (Belgique).
# 		  509 Matinée de Septembre.
# 		  510 Intérieur en Campine.
# 	cat_pcp_1902.pdf_page_64.xml traité
# 57 – Traitement de cat_pcp_1902.pdf_page_65.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      VIEUILLE (G.).
# 	       S. F. P. 10, rue Dalayrac, Fontenay-sous- Bois (Seine).
# 		  511 Les Lys. A.
# 		  512 Fleurs des Près. A.
# 		  513 Notre-Dame de Paris. Le soleil déclinait; le soir, prompt à le suivre, Brunissait l'horizon... VICTOR HUGO.
# 	      VILLESTREUX (Comte de la).
# 	      P. C. P. - S. A. E. 27, rue Raynouard, Paris.
# 		  514 Fontaine à Tipoli. A. Ch.
# 		  515 Oasis de Tripoli. A. Ch.
# 	      WALLON (E.).
# 	       P. C. P. -S. A. E. -S. F. P. 65, rue de Prony, Paris.
# 		  516 Soirs de Bretagne. La Sortie des Sardinières. A. Br.
# 		  517 Soirs de Bretagne. Autour du Puits. A. Br.
# 		  518 Au Pardon de Notre-Dame de la Pitié.
# 		  519 Bords du Morbihan (Noyalo). A. Br.
# 		  520 Effet de Matin, Hennebont. A. Br.
# 	      WALLS.
# 	      47, Lothian Street, Édimbourg (Écosse).
# 		  521 Le Rouet.
# 	cat_pcp_1902.pdf_page_65.xml traité
# 58 – Traitement de cat_pcp_1902.pdf_page_66.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      WARBURG (Miss Agnès).
# 	      8, Porchester Terrace, Londres (Angleterre).
# 		  522 Le Journal. Pl.
# 		  523 Ursula. Pl.
# 		  524 Confluent de fleuve et mer. A. Pl.
# 		  525 Lac de Bala, pays de Galles. Pl.
# 	      WARBURG (J.-C.).
# 	      21, Pembridge Gardens, Londres (Angleterre).
# 		  526 Un Soleil. Pl.
# 		  527 Rayon de Soleil. Pl.
# 		  528 Boutique de Charpentier. Hollande. Pl.
# 		  529 Oostkapelle. Hollande. Pl.
# 		  530 Au “ Park ”. Londres. Br.
# 	      WASSERMANN (Dr Melville).
# 	      P. C. P. 1, rue du Général-Foy, Paris.
# 		  531 Noce Arabe au Caire en 1900. A. Ch.
# 	      WATTS LEE (Mme Francis).
# 	      63, Peter Parley, Road, Boston (U. S. A.).
# 		  532 Théodora. Pl.
# 		  533 Billy. Pl.
# 		  534 Milly. Pl.
# 	cat_pcp_1902.pdf_page_66.xml traité
# 59 – Traitement de cat_pcp_1902.pdf_page_67.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      WERNWAG (C.-J.).
# 	      709, Real Estate Trust, Blag, Phila¬ delphie (U. S. A.).
# 		  535 Étude à la Rembrandt. D. Pl.
# 		  536 Portrait de H. D.-D. Pl.
# 	      WETREMS (Ad.).
# 	       C. EF. 13, Hydraulique, Bruxelles.
# 		  537 Gros temps à marée haute. Ch.
# 	      WHITEHEAD.
# 	      George St, Alva (Écosse).
# 		  538 Dans le Bois. D. Pl.
# 		  539 Iris.
# 	      WUNDERLY.
# 	      Glaermischstraate, Zurich (Suisse).
# 		  540 “L'esprit planait au-dessus des eaux.” A. Pl. Dm.
# 		  541 Étude. A. Br.
# 	      YVON (Albert).
# 	      2, rue de l'Hôtel-de- Ville, Vincennes (Seine).
# 		  542 La Bonne Pipe. D.
# 		  543 Le Vieux Fumeur. D.
# 		  544 Magda. D.
# 		  545 Le Pont-Neuf au matin. D.
# 	cat_pcp_1902.pdf_page_67.xml traité
# 60 – Traitement de cat_pcp_1902.pdf_page_68.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
#
# 		Ce fichier ne contient pas d'entrées
#
# 	cat_pcp_1902.pdf_page_68.xml traité
# 61 – Traitement de cat_pcp_1902.pdf_page_69.xml
# 	1 – Vérification de la conformité du fichier alto
# 	2 – Vérification de la structure du fichier alto
# 	3 – Restructuration du fichier effectuée (fichier "_restructuration.xml" créé)
# 	4 – Extraction :
# 	      ZIMMERMAN (Walter).
# 	       S. P. DE PH. 10, South, 18th Street, Philadelphie (États-Unis).
# 		  546 Port de Boston. D. Pl.
# 		  547 Enfant à l'Épine. A. Pl.
# 	cat_pcp_1902.pdf_page_69.xml traité
#
# Résumé :
# 	61 fichiers traités
# 	230 entrées extraites
# 	230 auteurs signalés
# 	555 oeuvres extraites
#
# Analyse input ALTO :
# 	– 1 élément <TextLine> directement située sur <MainZone>
# 	- La segmentation est conforme à l'ontologie Segmonto
# Analyse output TEI :
# 	– Le document XML produit est conforme au schéma TEI et à l'ODD du projet.
#
# Chemin du dossier d'extraction : /Users/EstebanSanchez/TNAH_Git/IMAGO-Artl@s/Github_repos/Juliette_Janès/IMAGO-Catalogues-Jjanes/extractionCatalogs/exemples_output/extraction_PCP_1902

# %% [markdown]
# ## Interventions manuelles et gestion des erreurs

# %% [markdown]
# ### Adapter les regex

# %% [markdown]
# #### Regex de base

# %% [markdown]
# #### Regex Auteur

# %%
from extractionCatalogs.variables.exemple import auteur_recuperation_regex

# variable originale :
print(auteur_recuperation_regex)

# variable nouvelle
auteur_recuperation_regex = "Nouvelle regex pour l'exemple"
print(auteur_recuperation_regex)

# on écrit
exemple_ajout = "extractionCatalogs/variables/exemple_ajouts.py"
with open(exemple, mode="a") as f:
    f.write("\nauteur_recuperation_regex = '{}'\n".format(auteur_recuperation_regex))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from extractionCatalogs.variables.exemple import auteur_recuperation_regex
#       3 # variable originale :
#       4 print(auteur_recuperation_regex)
#
# File ~/TNAH_Git/IMAGO-Artl@s/Github_repos/Juliette_Janès/IMAGO-Catalogues-Jjanes/extractionCatalogs/extractionCatalogs/variables/exemple.py:9, in <module>
#       5 oeuvre_recuperation_regex = re.compile(r'^[*]*\d{1,4}[\.][ ](Bis|bis)*[ ]*[—]|^[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[\.]|^[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[—]|[*]*\d{1,4}[ ]*[-]|[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[–3 ]')
#       7 # =================================================================
#       8 # Variables ajoutées depuis "Guide – extraction de catalogues.ipynb"
# ----> 9 import exemple_ajouts
#
# ModuleNotFoundError: No module named 'exemple_ajouts'

# %%
from extractionCatalogs.variables.exemple import auteur_recuperation_regex


# ce print appelle la variable issue de "import"
print("\nvariable originale : \n{}".format(auteur_recuperation_regex))

# on peut assigner une nouvelle valeur à la variable "auteur_recuperation_regex" :

auteur_recuperation_regex = "Nouvelle regex"

# le print suivant appelle la nouvelle variable, puisqu'elle a changé de contenu
print("\nnouvelle variable : \n{}".format(auteur_recuperation_regex))


#=======================================================
# le code suivant sert à ajouter la variable au fichier :
exemple_ajout = "extractionCatalogs/variables/exemple_ajouts.py"
with open(exemple_ajout, mode="a") as f:
    f.write("\nauteur_recuperation_regex = '{}'\n".format(auteur_recuperation_regex))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from extractionCatalogs.variables.exemple import auteur_recuperation_regex
#       4 # ce print appelle la variable issue de "import"
#       5 print("\nvariable originale : \n{}".format(auteur_recuperation_regex))
#
# File ~/TNAH_Git/IMAGO-Artl@s/Github_repos/Juliette_Janès/IMAGO-Catalogues-Jjanes/extractionCatalogs/extractionCatalogs/variables/exemple.py:9, in <module>
#       5 oeuvre_recuperation_regex = re.compile(r'^[*]*\d{1,4}[\.][ ](Bis|bis)*[ ]*[—]|^[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[\.]|^[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[—]|[*]*\d{1,4}[ ]*[-]|[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[–3 ]')
#       7 # =================================================================
#       8 # Variables ajoutées depuis "Guide – extraction de catalogues.ipynb"
# ----> 9 import exemple_ajouts
#
# ModuleNotFoundError: No module named 'exemple_ajouts'

# %% [markdown]
# #### Regex Oeuvre

# %%
oeuvre_recuperation_regex = re.compile(r'^[*]*\d{1,4}[\.][ ](Bis|bis)*[ ]*[—]|^[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[\.]|^[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[—]|[*]*\d{1,4}[ ]*[-]|[*]*\d{1,4}[ ]*(Bis|bis)*[ ]*[–]')

# %% [markdown]
# #### Regex informations complémentaires

# %%
limitation_auteur_infobio_regex = re.compile(r'(— .*)')
# Regex : extrait le numero de l'oeuvre
numero_regex = re.compile(r'^(\S\d{1,4}|\d{1,4})')
# Regex : premiers caractères d'une ligne entière à identifier
ligne_secondaire_regex = re.compile(r'^([A-ZÉ]|[a-zé])')
# Regex : informations complementaires
info_comp_tiret_parenthese_regex = re.compile(r'—[ ]*.*|\(.*\)|[a-z]\. .*')

# %% [markdown]
# ### Messages d'erreur et problemes.txt

# %% [markdown]
# #### erreures antérieures au script : eScriptorium et input ALTO

# %% [markdown]
# - String directement dans mainZone au lieu d'avoir un textBlock : le script ne peux pas extraire le texte

# %% [markdown]
# #### Entrées non extraites : entry et entryEnd

# %% [markdown]
# #### Auteurs non extraits

# %% [markdown]
# #### Oeuvres non extraites

# %% [markdown]
# #### Informations complémentaires non extraites

# %% [markdown]
# ## Produire un tableur csv
